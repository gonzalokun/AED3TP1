# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tabla1 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla1
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                         1000             0             0            0
# 11                         1000             1             0            0
# 12                         1000             1             0            0
# 13                         1000             1             1            0
# 14                         1000             2             1            0
# 15                         1000             6             1            0
# 16                         1000             9             1            0
# 17                         1000            18             3            0
# 18                         1000            37             6            0
# 19                         1000            76            12            0
# 20                         1000           171            22            0
# 21                         1000           333            44            0
# ...

# %%
#list(tabla1)
listaPlot = [i for i in range(10, 29)]
graf1 = tabla1[["Fuerza Bruta", "Backtracking"]].plot(xticks=listaPlot,figsize=(10, 5), grid=True, title="Tiempo de ejecución entre los algoritmos de Fuerza Bruta y Backtracking")
graf1.set_xlabel("Tamaño del Conjunto")
graf1.set_ylabel("Tiempo de Ejecucion en milisegundos")
plt.savefig("G1.pdf")

# %%
tabla2 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla2
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                        10000             0             0            1
# 1010                      10000             0             0          124
# 2010                      10000             0             0          337
# 3010                      10000             0             0          572
# 4010                      10000             0             0          956
# 5010                      10000             0             0         1544
# 6010                      10000             0             0         1823
# 7010                      10000             0             0         2525
# 8010                      10000             0             0         3609
# 9010                      10000             0             0         3939
# 10010                     10000             0             0         4381
#
#                  PD Bottom Up
# Tamaño Conjunto
# ...

# %%
graf2 = tabla2[["PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Tiempo de ejecución entre los algoritmos Top Down y Bottom Up de programación dinámica con V=10000")
graf2.set_xlabel("Tamaño del Conjunto")
graf2.set_ylabel("Tiempo de Ejecucion en milisegundos")
plt.savefig("G2.pdf")

# %%
tabla3 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla3
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                       500000             1             0           41
# 11                       500000             0             0           50
# 12                       500000             1             0           57
# 13                       500000             2             0           55
# 14                       500000             2             1           61
# 15                       500000             6             1           63
# 16                       500000             9             1           70
# 17                       500000            21             3           72
# 18                       500000            40             5           76
# 19                       500000            85            12           87
# 20                       500000           174            22           89
# 21                       500000           359            44           86
# ...

# %%
graf3 = tabla3[[ "Fuerza Bruta", "Backtracking", "PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Tiempo de ejecución entre todos los algoritmos con V = 500000")
graf3.set_xlabel("Tamaño del Conjunto")
graf3.set_ylabel("Tiempo de Ejecucion en milisegundos")
plt.savefig("G3.pdf")

# %%
tabla4 = pd.read_csv("./output.csv", index_col="Valor Objetivo")
tabla4
# Out:
#                 Tamaño Conjunto  Fuerza Bruta  Backtracking  PD Top Down  \
# Valor Objetivo
# 10                        10000             0             0           12
# 1010                      10000             0             0          686
# 2010                      10000             0             0         1422
# 3010                      10000             0             0         1910
# 4010                      10000             0             0         2549
# 5010                      10000             0             0         3402
# 6010                      10000             0             0         3695
# 7010                      10000             0             0         4612
# 8010                      10000             0             0         5241
# 9010                      10000             0             0         5415
# 10010                     10000             0             0         4292
#
#                 PD Bottom Up
# Valor Objetivo
# ...

# %%
graf4 = tabla4[["PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Tiempo de ejecución entre los algoritmos Top Down y Bottom Up de programación dinámica con n = 10000")
graf4.set_xlabel("Valor Objetivo")
graf4.set_ylabel("Tiempo de Ejecucion en milisegundos")
plt.savefig("G4.pdf")

# %%
tabla5 = pd.read_csv("./output.csv", index_col="Valor Objetivo")
tabla5
# Out:
#                 Tamaño Conjunto  Fuerza Bruta  Backtracking  PD Top Down  \
# Valor Objetivo
# 10                         5000             0             0            6
# 1010                       5000             0             0          335
# 2010                       5000             0             0          609
# 3010                       5000             0             0          821
# 4010                       5000             0             0         1034
# 5010                       5000             0             0         1166
# 6010                       5000             0             0         1173
# 7010                       5000             0             0         1206
# 8010                       5000             0             0         1226
# 9010                       5000             0             0         1320
# 10010                      5000             0             0         1319
#
#                 PD Bottom Up
# Valor Objetivo
# ...

# %%
graf5 = tabla5[["PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Tiempo de ejecución entre los algoritmos Top Down y Bottom Up de programación dinámica con n = 5000")
graf5.set_xlabel("Valor Objetivo")
graf5.set_ylabel("Tiempo de Ejecucion en milisegundos")
plt.savefig("G5.pdf")

# %%
pepe = tabla5["PD Top Down"]/tabla5["PD Bottom Up"]
pepe
pepe.plot()

# %%
tabla6 = pd.read_csv("./outputComp.csv", index_col="Tamaño Conjunto")
tabla6
tabla6["Fuerza Bruta"].plot()

# %%
tabla7 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla7
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                          500      0.000000             0            0
# 11                          500      0.000000             0            0
# 12                          500      0.000000             0            0
# 13                          500      0.000009             0            0
# 14                          500      0.000009             0            0
# 15                          500      0.000008             0            0
# 16                          500      0.000009             1            0
# 17                          500      0.000010             3            0
# 18                          500      0.000008             6            0
# 19                          500      0.000008            13            0
# 20                          500      0.000008            25            0
# 21                          500      0.000008            49            0
# ...

# %%
listaPlot = [i for i in range(10, 29)]
graf7 = tabla7[["Fuerza Bruta"]].plot(xticks=listaPlot,figsize=(10, 5), grid=True, title="Algoritmo de Fuerza Bruta sobre n*2^n")
graf7.set_xlabel("Tamaño del Conjunto")
graf7.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf7.axis([10, 29, 0, 0.0001])
#graf7.set_xscale("log")
#graf7.set_yscale("log")
plt.savefig("G7.pdf")

# %%
tabla8 = pd.read_csv("./outputComp.csv", index_col="Tamaño Conjunto")
tabla8
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 15                          100             0  0.000000e+00            0
# 16                          100             0  9.536743e-07            0
# 17                          100             0  1.346364e-06            0
# 18                          100             0  1.271566e-06            0
# 19                          100             0  1.305028e-06            0
# 20                          100             0  1.287460e-06            0
# 21                          100             0  1.180740e-06            0
# 22                          100             0  1.083721e-06            0
# 23                          100             0  1.103982e-06            0
# 24                          100             0  1.065433e-06            0
# 25                          100             0  9.751320e-07            0
# 26                          100             0  9.410656e-07            0
# ...

# %%
listaPlot = [i for i in range(10, 32)]
graf8 = tabla8[["Backtracking"]].plot(xticks=listaPlot,figsize=(10, 5), grid=True, title="Algoritmo de Backtracking sobre n*2^n")
graf8.set_xlabel("Tamaño del Conjunto")
graf8.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf8.axis([15, 29, 0, 0.00001])
#graf8.set_xscale("log")
#graf8.set_yscale("log")
plt.savefig("G8.pdf")

# %%
tabla9 = pd.read_csv("./outputComp.csv", index_col="Tamaño Conjunto")
tabla9
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 500                       11001             0             0     0.000013
# 1000                      11001             0             0     0.000013
# 1500                      11001             0             0     0.000017
# 2000                      11001             0             0     0.000017
# 2500                      11001             0             0     0.000018
# 3000                      11001             0             0     0.000021
# 3500                      11001             0             0     0.000026
# 4000                      11001             0             0     0.000024
# 4500                      11001             0             0     0.000024
# 5000                      11001             0             0     0.000027
# 5500                      11001             0             0     0.000030
# 6000                      11001             0             0     0.000033
# ...

# %%
graf9 = tabla9[["PD Top Down"]].plot(figsize=(10, 5), grid=True, title="Algoritmo de PD Top Down sobre n*v")
graf9.set_xlabel("Tamaño del Conjunto")
graf9.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf9.axis([500, 11000, 0, 0.0001])
#graf9.set_xscale("log")
#graf9.set_yscale("log")
plt.savefig("G9.pdf")

# %%
tabla10 = pd.read_csv("./outputComp.csv", index_col="Tamaño Conjunto")
tabla10
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 500                       11001             0             0            0
# 1000                      11001             0             0            0
# 1500                      11001             0             0            0
# 2000                      11001             0             0            0
# 2500                      11001             0             0            0
# 3000                      11001             0             0            0
# 3500                      11001             0             0            0
# 4000                      11001             0             0            0
# 4500                      11001             0             0            0
# 5000                      11001             0             0            0
# 5500                      11001             0             0            0
# 6000                      11001             0             0            0
# ...

# %%
graf10 = tabla10[["PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Algoritmo de PD Bottom Up sobre n*v con V = 11001")
graf10.set_xlabel("Tamaño del Conjunto")
graf10.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf10.axis([500, 11000, 0, 0.00004])
#graf10.set_xscale("log")
#graf10.set_yscale("log")
plt.savefig("G10.pdf")

# %%
tabla11 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla11
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                           40             0             0            0
# 11                           40             0             0            0
# 12                           40             0             0            0
# 13                           40             1             0            0
# 14                           40             2             0            0
# 15                           40             4             1            0
# 16                           40             8             1            0
# 17                           40            19             3            0
# 18                           40            39             6            0
# 19                           40            87            12            0
# 20                           40           171            27            0
# 21                           40           387            49            0
# ...

# %%
listaPlot = [i for i in range(10, 29)]
graf11 = tabla11[["Fuerza Bruta", "Backtracking"]].plot(xticks=listaPlot, figsize=(10, 5), grid=True, title="Fuerza Bruta vs Backtracking")
graf11.set_xlabel("Tamaño del Conjunto")
graf11.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf11.axis([20, 28, 0, 60000])
#graf11.set_xscale("log")
#graf11.set_yscale("log")
plt.savefig("G11v2.pdf")

# %%
tabla12 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla12
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                        10011             0             0            0
# 510                       10011             0             0           60
# 1010                      10011             0             0          129
# 1510                      10011             0             0          228
# 2010                      10011             0             0          307
# 2510                      10011             0             0          450
# 3010                      10011             0             0          569
# 3510                      10011             0             0          725
# 4010                      10011             0             0          901
# 4510                      10011             0             0         1116
# 5010                      10011             0             0         1363
# 5510                      10011             0             0         1535
# ...

# %%
#listaPlot = [i for i in range(10, 29)]
graf12 = tabla12[["PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="PD Top Down vs PD Bottom Up con V = 10011")
graf12.set_xlabel("Tamaño del Conjunto")
graf12.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf12.axis([0, 10000, 0, 6000])
#graf10.set_xscale("log")
#graf10.set_yscale("log")
plt.savefig("G12.pdf")

# %%
tabla13 = pd.read_csv("./output.csv", index_col="Valor Objetivo")
tabla13
# Out:
#                 Tamaño Conjunto  Fuerza Bruta  Backtracking  PD Top Down  \
# Valor Objetivo
# 10                        10011             0             0            9
# 510                       10011             0             0          351
# 1010                      10011             0             0          637
# 1510                      10011             0             0         1041
# 2010                      10011             0             0         1218
# 2510                      10011             0             0         1545
# 3010                      10011             0             0         1815
# 3510                      10011             0             0         2087
# 4010                      10011             0             0         2337
# 4510                      10011             0             0         2603
# 5010                      10011             0             0         2971
# 5510                      10011             0             0         3025
# ...

# %%
#listaPlot = [i for i in range(10, 29)]
graf13 = tabla13[["PD Top Down", "PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="PD Top Down vs PD Bottom Up con N = 10011")
graf13.set_xlabel("Valor Objetivo")
graf13.set_ylabel("Tiempo de Ejecucion en milisegundos")
#graf13.axis([0, 10000, 0, 6000])
#graf10.set_xscale("log")
#graf10.set_yscale("log")
plt.savefig("G13.pdf")

# %%
tabla14 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla14
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                      1000000             0             0            0
# 11                      1000000             0             0            0
# 12                      1000000             0             0            0
# 13                      1000000             0             0            0
# 14                      1000000             0             0            0
# 15                      1000000             0             0            0
# 16                      1000000             0             1            0
# 17                      1000000             0             3            0
# 18                      1000000             0             6            0
# 19                      1000000             0            15            0
# 20                      1000000             0            38            0
# 21                      1000000             0            54            0
# ...

# %%
listaPlot = [i for i in range(10, 27)]
graf14 = tabla14[["Backtracking", "PD Bottom Up"]].plot(xticks=listaPlot, figsize=(10, 5), grid=True, title="Backtracking vs PD Bottom Up con V = 1000000")
graf14.set_xlabel("Tamaño del Conjunto")
graf14.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf14.axis([10, 26, 0, 10000])
#graf10.set_xscale("log")
#graf10.set_yscale("log")
plt.savefig("G14.pdf")

# %%
tabla15 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla15
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                        10000             0             0            0
# 11                        10000             0             0            0
# 12                        10000             0             0            0
# 13                        10000             0             0            0
# 14                        10000             0             0            0
# 15                        10000             0             1            0
# 16                        10000             0             2            0
# 17                        10000             0             4            0
# 18                        10000             0             8            0
# 19                        10000             0            13            0
# 20                        10000             0            29            0
# 21                        10000             0            56            0
# ...

# %%
listaPlot = [i for i in range(10, 29)]
graf15 = tabla15[["Backtracking", "PD Bottom Up"]].plot(xticks=listaPlot, figsize=(10, 5), grid=True, title="Backtracking vs PD Bottom Up con V = 10000")
graf15.set_xlabel("Tamaño del Conjunto")
graf15.set_ylabel("Tiempo de Ejecucion en milisegundos")
#graf15.axis([10, 28, 0, 7000])
#graf15.set_xscale("log")
#graf15.set_yscale("log")
plt.savefig("G15.pdf")

# %%
tabla16 = pd.read_csv("./outputComp.csv", index_col="Valor Objetivo")
tabla16
# Out:
#                 Tamaño Conjunto  Fuerza Bruta  Backtracking  PD Top Down  \
# Valor Objetivo
# 10                        10011             0             0            0
# 510                       10011             0             0            0
# 1010                      10011             0             0            0
# 1510                      10011             0             0            0
# 2010                      10011             0             0            0
# 2510                      10011             0             0            0
# 3010                      10011             0             0            0
# 3510                      10011             0             0            0
# 4010                      10011             0             0            0
# 4510                      10011             0             0            0
# 5010                      10011             0             0            0
# 5510                      10011             0             0            0
# ...

# %%
graf16 = tabla16[["PD Bottom Up"]].plot(figsize=(10, 5), grid=True, title="Algoritmo de PD Bottom Up sobre n*v con N = 11001")
graf16.set_xlabel("Tamaño del Conjunto")
graf16.set_ylabel("Tiempo de Ejecucion en milisegundos")
graf16.axis([10, 10000, 0, 0.00008])
#graf10.set_xscale("log")
#graf10.set_yscale("log")
plt.savefig("G16.pdf")
