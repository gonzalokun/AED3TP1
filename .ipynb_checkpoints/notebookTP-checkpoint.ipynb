# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tabla1 = pd.read_csv("./output.csv", index_col="Tamaño Conjunto")
tabla1
# Out:
#                  Valor Objetivo  Fuerza Bruta  Backtracking  PD Top Down  \
# Tamaño Conjunto
# 10                         1000             0             0            0
# 11                         1000             1             0            0
# 12                         1000             1             0            0
# 13                         1000             1             1            0
# 14                         1000             2             1            0
# 15                         1000             6             1            0
# 16                         1000             9             1            0
# 17                         1000            18             3            0
# 18                         1000            37             6            0
# 19                         1000            76            12            0
# 20                         1000           171            22            0
# 21                         1000           333            44            0
# ...

# %%
#list(tabla1)
graf1 = tabla1[["Fuerza Bruta", "Backtracking"]].plot(figsize=(10, 5), grid=True, title="Tiempo de ejecución entre los algoritmos de Fuerza Bruta y Backtacking")
graf1.set_xlabel("Tamaño del Conjunto")
graf1.set_ylabel("Tiempo de Ejecucion en milisegundos")
# Out:
# Text(0,0.5,'Tiempo de Ejecucion en milisegundos')
